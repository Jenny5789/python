# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_05_03_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Q1. a와 b출력하기
#
# 정수 a와 b가 주어집니다. 각 수를 입력받아 입출력 예와 같은 형식으로 출력하는 코드를 작성해 보세요.

# %%
a, b = map(int, input().strip().split(' '))
print('a =',a)
print('b =',b)
# Out:
# 4 5
# a = 4
# b = 5

# %% [markdown]
# # 💻 Q2. 대소문자 바꿔서 출력하기
#
# 영어 알파벳으로 이루어진 문자열 str이 주어집니다. 각 알파벳을 대문자는 소문자로 소문자는 대문자로 변환해서 출력하는 코드를 작성해 보세요.

# %%
입력 = 'aBcDeFg'

# %%
a = 입력.upper()
print(a)
a =  입력.lower()
print(a)
# Out:
# ABCDEFG
# abcdefg

# %%
a = 'aBcDeFg'
result = a.swapcase()
print(result)
# Out:
# AbCdEfG

# %% [markdown]
# # 💻 Q3.  덧셈식 출력하기
# 두 정수 a, b가 주어질 때 다음과 같은 형태의 계산식을 출력하는 코드를 작성해 보세요.
#
# a + b = c

# %%
a = 4
b = 5

# %%
a, b = map(int, input().strip().split(' '))
print('a = ',  a)
print('b = ', b)
print('a + b = ', a + b)
print(f"{a} + {b} = {a+b}")
# Out:
# 4 5
# a =  4
# b =  5
# a + b =  9
# 4 + 5 = 9

# %% [markdown]
# # 💻 Q4. 문자열 돌리기
# 문자열을 시계방향으로 90도 돌려서 아래 입출력 예와 같이 출력하는 코드를 작성해 보세요.

# %%
a = 'abcde'

# %%
for i in a:
    print(i)
# Out:
# a
# b
# c
# d
# e

# %% [markdown]
# # 💻 Q5. 문자열 곱하기
# 문자열 my_string과 정수 k가 주어질 때, my_string을 k번 반복한 문자열을 return 하는 solution 함수를 작성해 주세요.

# %%
my_string = 'string'
k = 3

# %%
my_string = "love"
k = 10

# %%
print(my_string * k)
# Out:
# lovelovelovelovelovelovelovelovelovelove

# %% [markdown]
# # 💻 Q6. 배열의 원소 삭제하기
# 정수 배열 arr과 delete_list가 있습니다. arr의 원소 중 delete_list의 원소를 모두 삭제하고 남은 원소들은 기존의 arr에 있던 순서를 유지한 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
arr = [293, 1000, 395, 678, 94]
delete_list = [94, 777, 104, 1000, 1, 12]

# %%
arr = [110, 66, 439, 785, 1]
delete_list = [377, 823, 119, 43]

# %%
answer = []
for i in arr:
    if i not in delete_list:
       answer.append(i)
print(answer)
# Out:
# [110, 66, 439, 785, 1]

# %% [markdown]
# # 💻 Q7. 문자열로 변환
# 정수 n이 주어질 때, n을 문자열로 변환하여 return하도록 solution 함수를 완성해주세요.

# %%
n = 123

# %%
answer = str(n)

print(answer)
print(type(answer))
# Out:
# 123
# <class 'str'>

# %% [markdown]
# # 💻 Q8. 문자열을 정수로 변환하기
#
# 숫자로만 이루어진 문자열 n_str이 주어질 때, n_str을 정수로 변환하여 return하도록 solution 함수를 완성해주세요.

# %%
n_str = "10"

# %%
n_str = "8542"

# %%
type(n_str)
# Out:
# str

# %%
answer = int(n_str)
print(type(answer))
# Out:
# <class 'int'>

# %% [markdown]
# # 💻 Q9. 문자열 정수의 합
# 한 자리 정수로 이루어진 문자열 num_str이 주어질 때, 각 자리수의 합을 return하도록 solution 함수를 완성해주세요.

# %%
num_str = "123456789"

# %%
num_str = "1000000"

# %%
sum = 0
for i in num_str:
    sum = sum + int(i)

print(sum)
# Out:
# 45

# %% [markdown]
# # 💻 10. 뒤에서 5등 위로
# 정수로 이루어진 리스트 num_list가 주어집니다. num_list에서 가장 작은 5개의 수를 제외한 수들을 오름차순으로 담은 리스트를 return하도록 solution 함수를 완성해주세요.

# %%
num_list = [12, 4, 15, 46, 38, 1, 14, 56, 32, 10]

# %%
num_list.sort()
print(num_list)
print(num_list[5:])
# Out:
# [1, 4, 10, 12, 14, 15, 32, 38, 46, 56]
# [15, 32, 38, 46, 56]
