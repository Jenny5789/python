# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_04_19_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###💻 4/18 문제 이어풀기 - Q2. 모음 제거
# 영어에선 a, e, i, o, u 다섯 가지 알파벳을 모음으로 분류합니다. 문자열 my_string이 매개변수로 주어질 때 모음을 제거한 문자열을 return하도록 solution 함수를 완성해주세요.

# %%
my_string = "bus"

# %%
my_string = "nice to meet you"

# %% [markdown]
# - 변수:
#     * 입력되는 데이터=my_string
#     * 제거될 변수(aeiou) =모음
#     * 출력되는 값 = result
#
# - 작업:
#     *   문자열 데이터 입력 받아
#     *   문자 하나 하나 비교 확인 --> split
#     *   모음이 있는지 확인
#     *   모임이 있다면 제거/ 없다면 그 다음 모음 확인-->  if, 제거할 문자를 알고 있으니 remove 사용
#     *   문자열 끝까지 문자 하나하나 확인 반복  ->   문자열 몇 개인지 모름->  for 문 반복
#     *   비교확인할 문자가 없다면 프린트

# %%
my_string= "bus"
모음 = "aeiou"

비교 = my_string.split("")
print(my_string)
print(모음)

my_string.remove("u")
print(my_string)

# for i in range(len(my_string)):
#     if i == 모음:
#         my_string.remove(모음)
#     else:
#         i +=1
# print(my_string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3334/974695407.py in <cell line: 0>()
#       2 모음 = "aeiou"
#       3
# ----> 4 비교 = my_string.split("")
#       5 print(my_string)
#       6 print(모음)
#
# ValueError: empty separator

# %% [markdown]
# 풀 고 싶 다아
