# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/practice/codingtest/2026_05/2026_05_27_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👩‍💻 01. JadenCase 문자열 만들기
#
# JadenCase란 모든 단어의 첫 문자가 대문자이고, 그 외의 알파벳은 소문자인 문자열입니다.
#
#  단, 첫 문자가 알파벳이 아닐 때에는 이어지는 알파벳은 소문자로 쓰면 됩니다. (첫 번째 입출력 예 참고)
#
# 문자열 s가 주어졌을 때, s를 JadenCase로 바꾼 문자열을 리턴하는 함수, solution을 완성해주세요.

# %%
s = "3people unFollowed me"

# %%
word = s.split(" ")
for i in range(len(word)):
    first = word[i][0]
  #  print(first)

    if first.isdigit():
        first_join = "".join(first)
        print(answer)


    else:
        first = first.title()
        first_join = "".join(first)
        print(answer)
# Out:
# Mpeople unFollowed me
# Mpeople unFollowed me
# Mpeople unFollowed me

# %%
word = s.split(" ")
print(word)
for i in range(len(word)):
    first = word[i][0]
  #  print(first)

    if first.isdigit():
        first_join = "".join(first)
        answer = first_join + s[1:len(word[i])]
        print(answer)


    else:
        first = first.title()
        first_join = "".join(first)
        answer = first_join + s[1:len(word[i])]
        print(answer)
# Out:
# ['3people', 'unFollowed', 'me']
# 3people
# Upeople un
# Mp

# %%
answer = []
word = s.split(" ")
for i in range(len(word)):

    first = word[i][0]

    if first.isdigit():
        first_word = first + word[i][1:]
        fwc = first_word.capitalize()
        answer.append(fwc)
#        print(answer)

    else:
        first = first.title()
        first_word = first + word[i][1:]
        fwc = first_word.capitalize()
        answer.append(fwc)
#        print(answer)

    rea_answer = ' '.join(answer)
print(rea_answer)
# Out:
# 3people Unfollowed Me

# %%
def solution(s):
    answer = []
    word = s.split(" ")
    for i in range(len(word)):

        first = word[i][0]

        if first.isdigit():
            first_word = first + word[i][1:]
            fwc = first_word.capitalize()
            answer.append(fwc)

        else:
            first = first.title()
            first_word = first + word[i][1:]
            fwc = first_word.capitalize()
            answer.append(fwc)

        rea_answer = ' '.join(answer)
    return rea_answer

# %%
solution(s)
# Out:
# '3people Unfollowed Me'

# %%
s = "3people unFollowed me"

# %%
s = "for the last week"

# %%
s = "3people unFollowed     me"

# %%
## 공백문자 연속 나올 경우
answer = []
space = ' '.join(s.split())
print(space)

text = space.strip()
print(text)

word = text.split(" ")
print(word)
for i in range(len(word)):

    first = word[i][0]

    if first.isdigit():
        first_word = first + word[i][1:]
        fwc = first_word.capitalize()
        answer.append(fwc)

    else:
        first = first.title()
        first_word = first + word[i][1:]
        fwc = first_word.capitalize()
        answer.append(fwc)

    rea_answer = ' '.join(answer)
print(rea_answer)
# Out:
# 3people unFollowed me
# 3people unFollowed me
# ['3people', 'unFollowed', 'me']
# 3people Unfollowed Me

# %%
def solution(s):
    answer = []
    space = ' '.join(s.split())

    text = space.strip()

    word = text.split(' ')
    for i in range(len(word)):

        first = word[i][0]

        if first.isdigit():
            first_word = first + word[i][1:]
            fwc = first_word.capitalize()
            answer.append(fwc)

        else:
            first = first.title()
            first_word = first + word[i][1:]
            fwc = first_word.capitalize()
            answer.append(fwc)

        rea_answer = ' '.join(answer)
    return rea_answer

# %%
s = "3people unFollowed     me"
solution(s)
# Out:
# '3people Unfollowed Me'
