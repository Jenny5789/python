# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/practice/codingtest/2026_05/2026_05_30_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👩‍💻 01. x만큼 간격이 있는 n개의 숫자
#
# 함수 solution은 정수 x와 자연수 n을 입력 받아, x부터 시작해 x씩 증가하는 숫자를 n개 지니는 리스트를 리턴해야 합니다. 다음 제한 조건을 보고, 조건을 만족하는 함수, solution을 완성해주세요.

# %%
x = 2
n = 5

# %%
x = 4
n = 3

# %%
x = -4
n = 2

# %%
x * n
# Out:
# -8

# %%
answer = []
for i in range(1, n+1):
    answer.append(x * i)
print(answer)
# Out:
# [-4, -8]

# %%
answer = [(x * i) for i in range(1, n+1)]
print(answer)
# Out:
# [-4, -8]

# %%
def solution(x, n):
    answer = [(x * i) for i in range(1, n+1)]
    return answer
