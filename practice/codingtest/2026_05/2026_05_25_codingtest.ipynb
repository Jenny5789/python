# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/practice/codingtest/2026_05/2026_05_25_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👩‍💻 01. 최대공약수와 최소공배수
#
# 두 수를 입력받아 두 수의 최대공약수와 최소공배수를 반환하는 함수, solution을 완성해 보세요. 배열의 맨 앞에 최대공약수, 그다음 최소공배수를 넣어 반환하면 됩니다. 예를 들어 두 수 3, 12의 최대공약수는 3, 최소공배수는 12이므로 solution(3, 12)는 [3, 12]를 반환해야 합니다.

# %%
n = 3
m = 12

# %%
answer = []

# %%
# n의 최소공배수
n_LCM = []
for i in range(1, n+1, 1):
    result = n * i
    n_LCM.append(result)
print(f"{n}의 공배수는 {n_LCM}...")

# m의 최소공배수
m_LCM = []
for i in range(1, m+1, 1):
    result = m * i
    m_LCM.append(result)
print(f"{m}의 공배수는 {m_LCM}...")
# Out:
# 3의 공배수는 [3, 6, 9]...
# 12의 공배수는 [12, 24, 36, 48, 60, 72, 84, 96, 108, 120, 132, 144]...

# %%
### 최대공약수 구하기 ###
# 유클리드 호제법: 두 양의 정수 혹은 두 다항식의 최대공약수를 구하는 알고리즘이다.
# 180과 108의 최대공약수
# 180 ＝ 108×1 ＋ 72
# 108 ＝  72×1 ＋ 36
#  72 ＝  36×2 ＋  0
# 최대공약수는 36이다.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # 👩‍💻 02. 이상한 문자 만들기
#
# 문자열 s는 한 개 이상의 단어로 구성되어 있습니다. 각 단어는 하나 이상의 공백문자로 구분되어 있습니다. 각 단어의 짝수번째 알파벳은 대문자로, 홀수번째 알파벳은 소문자로 바꾼 문자열을 리턴하는 함수, solution을 완성하세요.
#
#
# 제한 사항
# - 문자열 전체의 짝/홀수 인덱스가 아니라, 단어(공백을 기준)별로 짝/홀수 인덱스를 판단해야합니다.
# - 첫 번째 글자는 0번째 인덱스로 보아 짝수번째 알파벳으로 처리해야 합니다.

# %%
s = "try hello world"

# %%
print(range(len(s)))
for i in s:
    print(i)

for i in range(len(s)):
    print(s[i])
# Out:
# range(0, 15)
# T
# R
# Y
#
# H
# E
# L
# L
# O
#
# W
# O
# R
# L
# D
# T
# R
# Y
#
# H
# E
# L
# L
# O
#
# W
# O
# R
# L
# D

# %%
print(s.upper())
print(s.lower())
# Out:
# TRY HELLO WORLD
# try hello world

# %%
#for i in s:
answer = []
for i in range(len(s)):

    if i == 0:
        s = s.upper()
        answer.append(s)

    elif i % 2 == 1:
        s = s.lower()
        answer.append(s)
    else:
        s = s.upper()
        answer.append(s)

answer.append(s)

print(answer)
# Out:
# ['TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'try hello world', 'TRY HELLO WORLD', 'TRY HELLO WORLD']

# %%
answer = []
for i in range(len(s)):

        if i == 0:
            s = s.upper()
            answer.append(s[i])

        elif i % 2 == 1:
            s = s.lower()
            answer.append(s[i])
        else:
            s = s.upper()
            answer.append(s[i])

print(answer)
# Out:
# ['T', 'r', 'Y', ' ', 'H', 'e', 'L', 'l', 'O', ' ', 'W', 'o', 'R', 'l', 'D']

# %%
answer = ''
for i in range(len(s)):

    if i == 0:
        s = s.upper()
        answer += s[i]

    elif i % 2 == 1:
        s = s.lower()
        answer += s[i]

    elif i % 2 == 0:
        s = s.upper()
        answer += s[i]

print(answer)
# Out:
# TrY HeLlO WoRlD

# %%
s  = "try hello world"

# %%
def solution(s):
    answer = ''
    for i in range(len(s)):

        if i == 0:
            s = s.upper()
            answer += s[i]

        elif i % 2 == 1:
            s = s.lower()
            answer += s[i]

        elif i % 2 == 0:
            s = s.upper()
            answer += s[i]

    return answer

# %%
# 각 단어의 첫 번째 대문자!!!
word = s.split(" ")
print(word)
for i in range(len(s)):
    print(word[i])

for i in range(len(s)):
    if i % 2 == 0:
        s.title()
    print(s)
# Out:
# ['try', 'hello', 'world']
# try
# hello
# world
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_5087/1440536908.py in <cell line: 0>()
#       3 print(word)
#       4 for i in range(len(s)):
# ----> 5     print(word[i])
#       6
#       7 for i in range(len(s)):
#
# IndexError: list index out of range

# %%
s  = "try hello world"
print(s.title())
word_index = 0
# Out:
# Try Hello World

# %%
#solution(s):
answer = ''
idx = 0
for i in range(len(s)):

    if s[i] == ' ':
        answer += s[i]
        idx = 0
        continue

    if i == 0:
        s = s.upper()
        answer += s[i]

    elif i % 2 == 1:
        s = s.lower()
        answer += s[i]

    elif i % 2 == 0:
        s = s.upper()
        answer += s[i]

    idx += 1

print(answer)
# Out:
# TrY HeLlO WoRlD

# %%
def solution(s):
    answer = ''
    text = 0
    for i in range(len(s)):

        if s[i] == ' ':
            answer += s[i]
            text = 0
            continue

        if text == 0:
            s = s.upper()
            answer += s[i]

        elif text % 2 == 1:
            s = s.lower()
            answer += s[i]

        elif text % 2 == 0:
            s = s.upper()
            answer += s[i]

        text += 1

    return answer
