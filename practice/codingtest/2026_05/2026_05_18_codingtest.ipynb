# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/practice/codingtest/2026_05/2026_05_19_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👩‍💻 01. 문자열 내 p와 y의 개수
#
# 대문자와 소문자가 섞여있는 문자열 s가 주어집니다. s에 'p'의 개수와 'y'의 개수를 비교해 같으면 True, 다르면 False를 return 하는 solution를 완성하세요. 'p', 'y' 모두 하나도 없는 경우는 항상 True를 리턴합니다. 단, 개수를 비교할 때 대문자와 소문자는 구별하지 않습니다.
#
# 예를 들어 s가 "pPoooyY"면 true를 return하고 "Pyy"라면 false를 return합니다.
#
# > 제한사항
# - 문자열 s의 길이 : 50 이하의 자연수
# - 문자열 s는 알파벳으로만 이루어져 있습니다.

# %%
s = "pPoooyY"

# %%
s = "Pyy"

# %%
# 대소문자 구별 안함
lower = s.lower()
# p의 개수 y의 개수 비교

print(lower.count('p'))
print(lower.count('y'))

# 같으면 True 다르면 False
# Out:
# 2
# 2

# %%
count_p = lower.count('p')
count_y = lower.count('y')

if count_p == count_y:
    print("True")
else:
    print("False")
# Out:
# True

# %%
def solution(s):
    lower = s.lower()
    count_p = lower.count('p')
    count_y = lower.count('y')

    if count_p == count_y:
        return True
    else:
        return False

# %%
s = "pPoooyY"
solution(s)
# Out:
# True

# %%
s = "Pyy"
solution(s)
# Out:
# False

# %% [markdown]
# # 👩‍💻 02. 음양 더하기
#
# 어떤 정수들이 있습니다. 이 정수들의 절댓값을 차례대로 담은 정수 배열 absolutes와 이 정수들의 부호를 차례대로 담은 불리언 배열 signs가 매개변수로 주어집니다. 실제 정수들의 합을 구하여 return 하도록 solution 함수를 완성해주세요.

# %%
absolutes = [4,7,12]
signs = [True,False,True]

# %%
# absolutes[0]
# signs[0]

# signs가 True 라면
#     absolutes 는 그대로
# 아니라면 False:
#     absolutes는 -1곱해

# answer에 입력해놔

# answer.sum 결과 출력

# %%
for i in range(len(absolutes)):
    if signs[i] == True:

        print(absolutes[i])
    else:
        print(-1 * absolutes[i])
# Out:
# 4
# -7
# 12

# %%
result = []
for i in range(len(absolutes)):
    if signs[i] == True:

        positive = (absolutes[i])
        result.append(positive)
    else:
        negative = (-1 * absolutes[i])
        result.append(negative)

print(result)

answer = sum(result)
print(answer)
# Out:
# [-1, -2, 3]
# 0

# %%
def solution(absolutes, signs):
    result = []
    for i in range(len(absolutes)):
        if signs[i] == True:

            positive = (absolutes[i])
            result.append(positive)
        else:
            negative = (-1 * absolutes[i])
            result.append(negative)

    answer = sum(result)
    return answer

# %%
absolutes = [1,2,3]
signs = [False, False, True]
solution(absolutes, signs)
# Out:
# 0

# %% [markdown]
# # 👩‍💻 03. 없는 숫자 더하기
# 0부터 9까지의 숫자 중 일부가 들어있는 정수 배열 numbers가 매개변수로 주어집니다.
#
# Numbers에서 찾을 수 없는 0부터 9까지의 숫자를 모두 찾아 더한 수를 return 하도록 solution 함수를 완성해주세요.

# %%
numbers = [1,2,3,4,6,7,8,0]

# %%
# 0 ~ 9 까지 넣어
# numbers에 없다면 print
# sum 하고 return

answer = []
for i in range(0,10,1):
    if i not in numbers:
        answer.append(i)
        print(answer)
print(sum(answer))
# Out:
# [5]
# [5, 9]
# 14

# %%
def solution(numbers):
    answer = []
    for i in range(0,10,1):
        if i not in numbers:
            answer.append(i)

    return (sum(answer))

# %%
numbers = [5,8,4,0,6,7,9]
solution(numbers)
# Out:
# 6

# %% [markdown]
# # 👩‍💻 04. 나누어 떨어지는 숫자 배열
# array의 각 element 중 divisor로 나누어 떨어지는 값을 오름차순으로 정렬한 배열을 반환하는 함수, solution을 작성해주세요.
#
# divisor로 나누어 떨어지는 element가 하나도 없다면 배열에 -1을 담아 반환하세요.

# %%
arr = [5, 9, 7, 10]
divisor = 5

# %%
arr = [2, 36, 1, 3]
divisor = 1

# %%
arr = [3, 2, 6]
divisor = 10

# %%
# arr에 있는 거 다 입력해봐

# arr 을 divisor로 나눠
# 만약 나머지가 0 이면
# answer에 붙여

# 오름차순 정렬
# 만약 아무것도 안 붙었어 -> -1 출력

# %%
answer = []
for i in range(len(arr)):
    if arr[i] % divisor == 0:
        answer.append(arr[i])
        answer.sort()

if len(answer) == 0:
    answer = [-1]

print(answer)
# Out:
# [1, 2, 3, 36]

# %%
def solution(arr,divisor):
    answer = []
    for i in range(len(arr)):
        if arr[i] % divisor == 0:
            answer.append(arr[i])
            answer.sort()

    if len(answer) == 0:
        answer = [-1]

    return answer

# %%
solution(arr,divisor)
# Out:
# [-1, 10]

# %% [markdown]
# # 👩‍💻 05. 서울에서 김서방 찾기
#
#
# String형 배열 seoul의 element중 "Kim"의 위치 x를 찾아, "김서방은 x에 있다"는 String을 반환하는 함수, solution을 완성하세요.
#
# seoul에 "Kim"은 오직 한 번만 나타나며 잘못된 값이 입력되는 경우는 없습니다.

# %%
seoul = ["Jane", "Kim"]

# %%
for i in range(len(seoul)):
    if seoul[i] == "Kim":
        print(seoul[i])

print(i)
print(f"김서방은 {i}에 있다.")
# Out:
# Kim
# 1
# 김서방은 1에 있다.

# %%
def solution(seoul):
    answer = ''
    for i in range(len(seoul)):
        if seoul[i] == "Kim":
            break

    return f"김서방은 {i}에 있다"
