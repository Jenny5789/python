# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/practice/codingtest/2026_05/2026_05_21_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 👩‍💻 01. 수박수박수박수박수?
# 길이가 n이고, "수박수박수박수...."와 같은 패턴을 유지하는 문자열을 리턴하는 함수, solution을 완성하세요.
#
# 예를들어 n이 4이면 "수박수박"을 리턴하고 3이라면 "수박수"를 리턴하면 됩니다.

# %%
n = 3

# %%
n = 4

# %%
# 길이 만큼 출력
# 홀수 : 수, 짝수 : 박

# watermelon = '수박' 세트.
# n / 2 만큼 watermelon 반복 붙여
# n % 2 == 1 이면 n/2 +1만큼 붙여
# watermelon[:n] 출력

# %%
answer = ''
watermelon = "수박"

rep = n / 2 + 1 # 홀수
print(rep)

word_list = int(rep) * watermelon
print(word_list)

print(word_list[:n])
# Out:
# 2.5
# 수박수박
# 수박수

# %%
answer = ''
watermelon = "수박"

if n % 2 == 1:
    rep = n / 2 + 1
else:
    rep = n /2

word_list = int(rep) * watermelon

print( word_list[:n])
# Out:
# 수박수

# %%
def solution(n):

    answer = ''
    watermelon = "수박"

    if n % 2 == 1:
        rep = n / 2 + 1
    else:
        rep = n /2

    word_list = int(rep) * watermelon

    return word_list[:n]

# %%
solution(n)
# Out:
# '수박수'

# %% [markdown]
# # 👩‍💻 02. 정수 제곱근 판별
#
# 임의의 양의 정수 n에 대해, n이 어떤 양의 정수 x의 제곱인지 아닌지 판단하려 합니다.
#
# n이 양의 정수 x의 제곱이라면 x+1의 제곱을 리턴하고, n이 양의 정수 x의 제곱이 아니라면 -1을 리턴하는 함수를 완성하세요.

# %%
n = 121

# %%
n = 3

# %%
# 양의 제곱근 확인
# 그렇다면 (n + 1) ^ 2
# 양의 정수가 아니라면 -1 반납

# %%
import math
a = math.sqrt(n)
print(a)
if  a % 1 == 0 :
    if a >= 0:
        a += 1
        print(int(a * a))
    else:
        print(-1)
else:
    print(-1)
# Out:
# 11.0
# 144

# %%
def solution(n):
    import math
    a = math.sqrt(n)

    if  a % 1 == 0 :
        if a >= 0:
            a += 1
            return (int(a * a))
        else:
            return -1
    else:
        return -1

# %%
solution(n)
# Out:
# -1

# %% [markdown]
# # 👩‍💻 03. 문자열 다루기 기본
#
# 문자열 s의 길이가 4 혹은 6이고, 숫자로만 구성돼있는지 확인해주는 함수, solution을 완성하세요. 예를 들어 s가 "a234"이면 False를 리턴하고 "1234"라면 True를 리턴하면 됩니다.
#
# 제한 사항
#
# - s는 길이 1 이상, 길이 8 이하인 문자열입니다.
# - s는 영문 알파벳 대소문자 또는 0부터 9까지 숫자로 이루어져 있습니다.

# %%
s = "a234"

# %%
s = "12345"

# %%
s = "1234"

# %%
number = ['1''2''3''4''5''6''7''8']
if len(s) == 4 or len(s) ==6:
    if '1''2''3''4''5''6''7''8' not in s:
        print("False")
    else:
        print("True")

# %%
if len(s) == 4 or len(s) == 6:
    print(s.isdigit())
else:
    print("False")
# Out:
# False

# %%
def solution(s):

    if len(s) == 4 or len(s) == 6:

        return s.isdigit()
    else:
        return False

# %%
solution(s)
# Out:
# True
