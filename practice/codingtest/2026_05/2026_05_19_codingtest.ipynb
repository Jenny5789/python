# %% [markdown]
# # 👩‍💻 01. 콜라츠 추측
#
# 1937년 Collatz란 사람에 의해 제기된 이 추측은, 주어진 수가 1이 될 때까지 다음 작업을 반복하면, 모든 수를 1로 만들 수 있다는 추측입니다. 작업은 다음과 같습니다.
#
#     1-1. 입력된 수가 짝수라면 2로 나눕니다.
#     1-2. 입력된 수가 홀수라면 3을 곱하고 1을 더합니다.
#     2. 결과로 나온 수에 같은 작업을 1이 될 때까지 반복합니다.
# 예를 들어, 주어진 수가 6이라면 6 → 3 → 10 → 5 → 16 → 8 → 4 → 2 → 1 이 되어 총 8번 만에 1이 됩니다. 위 작업을 몇 번이나 반복해야 하는지 반환하는 함수, solution을 완성해 주세요. 단, 주어진 수가 1인 경우에는 0을, 작업을 500번 반복할 때까지 1이 되지 않는다면 –1을 반환해 주세요.

# %%
n = 6

# %%
# 1이 될때 까지 반복해/ 1이 아니라면 계속해
    # 만약 입력된 수가 짝수라면 2로 나눠
    # 홀수라면 3을 곱하고 1을 더해
answer = []

while n != 1:
    if n % 2 == 0:
        n = n / 2

    else:
        n = n * 3 + 1
    answer.append(n)

print(answer)

count = (len(answer))

print(count)

# %%
num = 6

# %%
num = 626331

# %%
# 작업 500번 이상 --> -1 반환!

answer = []

while num != 1:
    if num % 2 == 0:
        num = num / 2

    else:
        num = num * 3 + 1
    answer.append(num)

count = (len(answer))


if count >= 500:
    print(-1)
else:
    print(count)

# %%
def solution(num):
    answer = []

    while num != 1:
        if num % 2 == 0:
            num = num / 2

        else:
            num = num * 3 + 1
        answer.append(num)

    count = (len(answer))


    if count >= 500:
        return -1
    else:
        return count

# %% [markdown]
# # 👩‍💻 02. 핸드폰 번호 가리기
#
# 프로그래머스 모바일은 개인정보 보호를 위해 고지서를 보낼 때 고객들의 전화번호의 일부를 가립니다.
# 전화번호가 문자열 phone_number로 주어졌을 때, 전화번호의 뒷 4자리를 제외한 나머지 숫자를 전부 *으로 가린 문자열을 리턴하는 함수, solution을 완성해주세요.

# %%
phone_number = "01033334444"

# %%
# 뒤에 4자리 외 모두 *로 변경하기
change_num = phone_number[0:-4]
print(change_num)

# %%
change_num = phone_number[0:-4]
print(change_num)

# change_num 을  * 로 변경하기
# cnange_num 의 길이만큼 * 로 변경
answer = ''
for i in range(len(change_num)):
    print("*")


return_num = phone_number[-4:]
print(return_num)

# %%
change_num = phone_number[0:-4]
print(change_num)

answer = ''
for i in range(len(change_num)):
    answer += '*'
print(answer)

return_num = phone_number[-4:]
print(return_num)


print(answer + return_num)

# %%
def solution(phone_number):
    change_num = phone_number[0:-4]

    answer = ''
    for i in range(len(change_num)):
        answer += '*'

    return_num = phone_number[-4:]

    return answer + return_num
