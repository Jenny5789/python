# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_05_06_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Q1. 공백으로 구분하기 1
# 단어가 공백 한 개로 구분되어 있는 문자열 my_string이 매개변수로 주어질 때,
#
#  my_string에 나온 단어를 앞에서부터 순서대로 담은 문자열 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
my_string = "i love you"

# %%
my_string = "programmers"

# %%
my_string.split(" ")
# Out:
# ['i', 'love', 'you']

# %% [markdown]
# # 💻 Q2. 공백으로 구분하기 2
# 단어가 공백 한 개 이상으로 구분되어 있는 문자열 my_string이 매개변수로 주어질 때,
#
# my_string에 나온 단어를 앞에서부터 순서대로 담은 문자열 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
my_string = " i    love  you"

# %%
my_string = " programmers "

# %%
print(my_string.strip())
# Out:
# i    love  you

# %%
a = my_string.strip()
print(a.split(" "))
# Out:
# ['i', '', '', '', 'love', '', 'you']

# %%
b = my_string.strip()
b.replace(" " , "")
print(b.split(" "))
# Out:
# ['i', '', '', '', 'love', '', 'you']

# %% [markdown]
# ---

# %%
b = " ".join(my_string.split())
print(b)
print(b.split(" "))
# Out:
# programmers
# ['programmers']

# %% [markdown]
# # 💻 Q3. ad 제거하기
# 문자열 배열 strArr가 주어집니다.
#
# 배열 내의 문자열 중 "ad"라는 부분 문자열을 포함하고 있는 모든 문자열을 제거하고
#
# 남은 문자열을 순서를 유지하여 배열로 return 하는 solution 함수를 완성해 주세요.

# %%
strArr = ["and","notad","abcd"]

# %%
strArr = ["there","are","no","a","ds"]

# %%
strArr.remove("ad")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10194/1555910838.py in <cell line: 0>()
# ----> 1 strArr.remove("ad")
#
# ValueError: list.remove(x): x not in list

# %%
for i in strArr:
    if "ad" in i:
        strArr.remove(i)
    else:
        print(i)

print(i)
# Out:
# and
# notad
