# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_04_28_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Q1. 홀짝 구분하기
# 자연수 n이 입력으로 주어졌을 때 만약 n이 짝수이면 "n is even"을, 홀수이면 "n is odd"를 출력하는 코드를 작성해 보세요.

# %%
a = int(input())
# Out:
# 3

# %%
if a % 2 == 0:
    print(f"{a} is even")
else:
    print(f"{a} is odd")
# Out:
# 3 is odd

# %% [markdown]
# # 💻 Q2. 정수부분
# 실수 flo가 매개 변수로 주어질 때, flo의 정수 부분을 return하도록 solution 함수를 완성해주세요.

# %%
flo = 1.42

# %%
flo = 69.32

# %%
print(int(flo))
# Out:
# 69

# %% [markdown]
# # 💻 Q3. 주사위 게임1
# 1부터 6까지 숫자가 적힌 주사위가 두 개 있습니다.  두 주사위를 굴렸을 때 나온 숫자를 각각 a, b라고 했을 때 얻는 점수는 다음과 같습니다.
#
# a와 b가 모두 홀수라면 a^2 + b^2 점을 얻습니다.
#
# a와 b 중 하나만 홀수라면 2 × (a + b) 점을 얻습니다.
#
# a와 b 모두 홀수가 아니라면 |a - b| 점을 얻습니다.
#
# 두 정수 a와 b가 매개변수로 주어질 때, 얻는 점수를 return 하는 solution 함수를 작성해 주세요.

# %%
a = 6
b = 10

# %%
if (a % 2 != 0) & (b % 2 != 0):
    print(a*a + b*b )

# %%
if (a % 2 != 0) | (b % 2 != 0):
    print(2 * (a + b) )

# %%
if (a % 2 != 0) | (b % 2 != 0):
    print(abs(a-b))

# %%
if (a % 2 != 0) & (b % 2 != 0):
    print(a*a + b*b )
elif (a % 2 != 0) | (b % 2 != 0):
    print(2 * (a + b) )
elif (a % 2 == 0) & (b % 2 == 0):
    print(abs(a-b))
# Out:
# 4

# %% [markdown]
# # 💻 Q4. 정수 찾기
# 정수 리스트 num_list와 찾으려는 정수 n이 주어질 때, num_list안에 n이 있으면 1을 없으면 0을 return하도록 solution 함수를 완성해주세요.

# %%
num_list = [1,2,3,4,5]
n = 3

# %%
num_list = [15,98,23,2,15]
n = 20

# %%
if n in num_list:
    print("1")
else:
    print("0")
# Out:
# 1

# %% [markdown]
# # 💻 Q5. 배열의 원소 삭제하기
# 정수 배열 arr과 delete_list가 있습니다. arr의 원소 중 delete_list의 원소를 모두 삭제하고 남은 원소들은 기존의 arr에 있던 순서를 유지한 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
arr = [293, 1000, 395, 678, 94]
delete_list = [94, 777, 104, 1000, 1, 12]

# %%
answer = list(filter(lambda x : x not in delete_list, arr))
print(answer)
# Out:
# [110, 66, 439, 785, 1]

# %%
arr = [110, 66, 439, 785, 1]
delete_list = [377, 823, 119, 43]
