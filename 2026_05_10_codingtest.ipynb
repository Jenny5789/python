# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_05_10_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Q1. 할 일 목록
# 오늘 해야 할 일이 담긴 문자열 배열 todo_list와 각각의 일을 지금 마쳤는지를 나타내는 boolean 배열 finished가 매개변수로 주어질 때,
#
#  todo_list에서 아직 마치지 못한 일들을 순서대로 담은 문자열 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
todo_list = ["problemsolving", "practiceguitar", "swim", "studygraph"]
finished = [True, False, True, False]

# %%
answer = []
for i in todo_list:
    for j in finished:
        if j == True:
            print("1")
        else:
            print("0")

# %%
answer = []
for j in finished:
    if j == True:
        answer.append(j)
    else:
        None
print(answer)
# Out:
# [True, True]

# %% [markdown]
# ---

# %%
ans = []
if finished[0] == True:
    ans.append(todo_list[0])
print(ans)
# Out:
# ['problemsolving']

# %%
answer = []
for i in range(len(todo_list)):
    if finished[i] == False:
        answer.append(todo_list[i])
print(answer)
# Out:
# ['practiceguitar', 'studygraph']

# %% [markdown]
# # 💻 Q2. 5명씩 묶기
# 최대 5명씩 탑승가능한 놀이기구를 타기 위해 줄을 서있는 사람들의 이름이 담긴 문자열 리스트 names가 주어질 때,
#
# 앞에서 부터 5명씩 묶은 그룹의 가장 앞에 서있는 사람들의 이름을 담은 리스트를 return하도록 solution 함수를 완성해주세요.
#
# 마지막 그룹이 5명이 되지 않더라도 가장 앞에 있는 사람의 이름을 포함합니다.

# %%
names = ["nami", "ahri", "jayce", "garen", "ivern", "vex", "jinx"]

# %%
answer = []
for i in range(len(names)):
    if i % 5 == 0:
        answer.append(names[i])
print(answer)
# Out:
# ['nami', 'vex']

# %% [markdown]
# # 💻 Q3. 홀수 vs 짝수
# 정수 리스트 num_list가 주어집니다.
#
# 가장 첫 번째 원소를 1번 원소라고 할 때,
# 홀수 번째 원소들의 합과 짝수 번째 원소들의 합 중 큰 값을 return 하도록 solution 함수를 완성해주세요.
#
# 두 값이 같을 경우 그 값을 return합니다.

# %%
num_list = [4, 2, 6, 1, 7, 6]

# %%
num_list = [-1, 2, 5, 6, 3]

# %%
range(0,len(num_list),2)  # 홀수
range(1,len(num_list),2)  # 짝수
# Out:
# range(1, 6, 2)

# %%
answer = []
for i in range(0,len(num_list),2):
   answer.append(num_list[i])
print(sum(answer))
# Out:
# 17

# %% [markdown]
# ---

# %%
# 홀수 합 구하기
# 짝수 합 구하기

# if 홀수 합 < 짝수 합
# return 짝수 합

# elif 홀수 합 > 짝수 합
# return 홀수 합

# else
# return 홀수 합(or 짝수 합)

# %%
odd = []
for i in range(0,len(num_list),2):
   odd.append(num_list[i])
print(sum(odd))


even = []
for i in range(1,len(num_list),2):
   even.append(num_list[i])
print(sum(even))
# Out:
# 7
# 8

# %%
if sum(odd) < sum(even):
    print(sum(even))
elif sum(odd) > sum(even):
    print(sum(odd))
else:
    print(sum(odd))
# Out:
# 8

# %% [markdown]
# # 💻 Q4. 순서 바꾸기
# 정수 리스트 num_list와 정수 n이 주어질 때,
#
#  num_list를 n 번째 원소 이후의 원소들과 n 번째까지의 원소들로 나눠
#
#  n 번째 원소 이후의 원소들을 n 번째까지의 원소들 앞에 붙인 리스트를 return하도록 solution 함수를 완성해주세요.

# %%
num_list = [2, 1, 6]
n = 1

# %%
num_list = [5, 2, 1, 7, 5]
n = 3

# %%
front = []
for i in range(0,n):
    front.append(num_list[i])
print(front)

back = []
for i in range(n, len(num_list)):
    back.append(num_list[i])
print(back)
# Out:
# [5, 2, 1]
# [7, 5]

# %%
answer = back + front
print(answer)
# Out:
# [7, 5, 5, 2, 1]
