# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/20260326_%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%98%88%EC%A0%9C_%EA%B0%80%EC%9C%84%EB%B0%94%EC%9C%84%EB%B3%B4(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👩‍🏫문제] 컴퓨터와 가위바위보 게임을 코딩해 보세요. 5전 3승제로 먼저 이기는 사람을 알려주고, 축하의 인사도 출력해 보세요

# %% [markdown]
# * 💻 '20260325_파이썬예제_가위바위보(2).ipynb'  def 이용하여 중복되는 것 정리

# %%
import random
def pick_RSP(who):
    RSP = None
    if who == "user":
        while True:
            user_RSP = input("R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: ").upper()
            if user_RSP in ['R', 'S', 'P']:
                return user_RSP
            print("다시 입력해주세요.")
    else:
        com_RSP = list_RSP[random.randint(0,2)]
        return com_RSP

# %%
def winner_count(user_RSP, com_RSP, score):
    winner = dict_RSP_judge[user_RSP][com_RSP]

    if winner == 'user':
        score['user'] = score['user'] + 1
        score['totla'] = score['total'] + 1
        print("사용자가 승리했어요. 축하합니다! (user:  {}전 {}승)".format(total_game,score['user']))

    elif winner == 'computer':
        score['com'] = score['com'] + 1
        score['total'] = score['total'] + 1
        print("컴퓨터가 승리했어요! (computer:  {}전 {}승)".format(total_game,score['user']))

    else:
        print("무승부예요. 다시 한번 해보세요.")

    return score

# %%
score = {'user':0,'com':0, 'total':0}

list_RSP = {0:'R', 1:'S', 2:'P'}
dict_RSP_judge = {
    'R':{'R':None,'S':'user','P':'computer'},
    'S':{'R':'computer','S':None,'P':'user'},
    'P':{'R':'user','S':'computer','P':None}
    }

while True:
    user_RSP = pick_RSP('user')
    com_RSP = pick_RSP('computer')
    score = winner_count(user_RSP, com_RSP, score)

    if score['user'] == 3:
        print("사용자가 최종 승리했습니다!")
        break
    elif score['com'] == 3:
        print("컴퓨터가 최종 승리했습니다!")
        break
# Out:
# R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: r
# 사용자가 승리했어요. 축하합니다! (user:  0전 1승)
# R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: r
# 무승부예요. 다시 한번 해보세요.
# R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: s
# 컴퓨터가 승리했어요! (computer:  0전 1승)
# R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: s
# 사용자가 승리했어요. 축하합니다! (user:  0전 2승)
# R(주먹) S(가위) P(보) 중 하나 선택해서 입력해주세요: r
# 사용자가 승리했어요. 축하합니다! (user:  0전 3승)
# 사용자가 최종 승리했습니다!
