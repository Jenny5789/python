# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_04_10_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Q1. 머쓱이는 학교에서 키 순으로 줄을 설 때 몇 번째로 서야 하는지 궁금해졌습니다. 머쓱이네 반 친구들의 키가 담긴 정수 배열 array와 머쓱이의 키 height가 매개변수로 주어질 때, 머쓱이보다 키 큰 사람 수를 return 하도록 solution 함수를 완성해보세요.

# %%
array = [111,149, 180, 192, 170]
height = 167

# %%
from typing import Counter
def solution(array, height):
    for i in range(len(array)):
        if i <= height:
            count = count + 1

# %%
array[0]
# Out:
# 111

# %%
array[1]
# Out:
# 149

# %%
range(len(array))
# Out:
# range(0, 5)

# %%
if array[0] <= 167:    # array[0] >= height:
    print("작다")
else:
    print('크다')
# Out:
# 작다

# %%
    for i in range(len(array)):
        if array[i] <= 167:    # array[0] >= height:
            print("작다")
        else:
            print('크다')
# Out:
# 작다
# 작다
# 크다
# 크다
# 크다

# %%
    for i in range(len(array)):
        if array[i] <= height:
            print("작다")
        else:
            print('크다')
# Out:
# 작다
# 작다
# 크다
# 크다
# 크다

# %%
result = ('크다', '작다', '작다', '작다')
result.count('작다')
# Out:
# 3

# %%
sum = 0
for i in range(len(array)):
    if array[i] <= height:
        print("작다")
    else:
        print('크다')
        sum = sum + 1

print (sum)
# Out:
# 작다
# 작다
# 크다
# 크다
# 크다
# 3

# %% [markdown]
# ---

# %% [markdown]
# ###📝 코딩 기초 트레이닝

# %% [markdown]
# ###💻 Q1. 알파벳으로 이루어진 문자열 myString이 주어집니다. 모든 알파벳을 대문자로 변환하여 return 하는 solution 함수를 완성해 주세요.

# %%
#myString: "aBcDeFg"

def solution(myString):
    answer = str.upper(myString)
    return answer

# %% [markdown]
# ###💻Q2. 두 정수 a, b와 boolean 변수 flag가 매개변수로 주어질 때, flag가 true면 a + b를 false면 a - b를 return 하는 solution 함수를 작성해 주세요.

# %% [markdown]
# 입출력 예 #1: 예제 1번에서 flag가 true이므로 a + b = (-4) + 7 = 3을 return 합니다.
#
# 입출력 예 #2: 예제 2번에서 flag가 false이므로 a - b = (-4) - 7 = -11을 return 합니다.

# %%
def solution(a, b, flag ):
    if flag == 'true':
        # boolean 값을 가지고 와야해서 문자 'true'가 아닌 true이어야 한다.
        answer = a + b
    else:
        answer = a - b

    return answer

# %%
def solution(a, b, flag ):
    if flag == true:
        answer = a + b
    else:
        answer = a - b

    return answer

# %% [markdown]
# ###💻Q3. 연산 ⊕는 두 정수에 대한 연산으로 두 정수를 붙여서 쓴 값을 반환합니다.
#
# 예를 들면 다음과 같습니다.
#
# 12 ⊕ 3 = 123
#
#  3 ⊕ 12 = 312
#
# 양의 정수 a와 b가 주어졌을 때,
#
#  a ⊕ b와 2 * a * b 중 더 큰 값을 return하는 solution 함수를 완성해 주세요.
#
# 단, a ⊕ b와 2 * a * b가 같으면 a ⊕ b를 return 합니다.

# %%
a = 12
b = 3
type(a)
A = str(a)
type(A)
print(A)
# Out:
# 12

# %%
B = str(b)
print(B)
type(B)
# Out:
# 3
# str

# %%
print(A+B)
# Out:
# 123

# %%
C = int(A+B)
print(C)
type(C)
# Out:
# 123
# int

# %% [markdown]
# ---

# %%
# a ⊕ b = ab
A = str(a)
B = str(b)

C = int(A+B)
print(C)
# Out:
# 123

# %%
D = 2 * a * b
print(D)
# Out:
# 72

# %%
if C > D:
    print(C)
elif C == D:
    print(C)
else:
    print(D)
# Out:
# 123

# %% [markdown]
# ###💻 Q4. 문자들이 담겨있는 배열 arr가 주어집니다.
# arr의 원소들을 순서대로 이어 붙인 문자열을 return 하는 solution함수를 작성해 주세요.

# %%
arr = ["a","b","c"]

# %%
print("".join(arr))
# Out:
# abc

# %% [markdown]
# ###💻 Q5. 연산 ⊕는 두 정수에 대한 연산으로 두 정수를 붙여서 쓴 값을 반환합니다. 예를 들면 다음과 같습니다.
#
# 12 ⊕ 3 = 123
#
# 3 ⊕ 12 = 312
#
# 양의 정수 a와 b가 주어졌을 때, a ⊕ b와 b ⊕ a 중 더 큰 값을 return 하는 solution 함수를 완성해 주세요.
#
# 단, a ⊕ b와 b ⊕ a가 같다면 a ⊕ b를 return 합니다.

# %%
# 형변환
a = 12
b = 3
A = str(a)
B = str(b)
C = int(A + B)
D = int(B + A)
print(C)
print(D)
# Out:
# 123
# 312

# %%
if C < D:
    print (D)
elif C == D:
    print (C)
else:
    print (C)
# Out:
# 312

# %% [markdown]
# ###💻 Q6.문자열 my_string과 정수 배열 index_list가 매개변수로 주어집니다. my_string의 index_list의 원소들에 해당하는 인덱스의 글자들을 순서대로 이어 붙인 문자열을 return 하는 solution 함수를 작성해 주세요.

# %%
my_string = "cvsgiorszzzmrpaqpe"
index_list=[16, 6, 5, 3, 12, 14, 11, 11, 17, 12, 7]

# %%
my_string[16]
# Out:
# 'p'

# %%
my_string[index_list[0]]
# Out:
# 'p'

# %%
index_list[0]
# Out:
# 16

# %%
range(len(index_list))
# Out:
# range(0, 11)

# %%
for i in range(0, 11):
    result = (my_string[i])
    print(result)
# Out:
# c
# v
# s
# g
# i
# o
# r
# s
# z
# z
# z

# %%
for i in range(0, 11):
    result = (my_string[index_list[i]])
    print(result, end:"")
# Out:
#   File "/tmp/ipykernel_26555/2977555192.py", line 3
#     print(result, end:"")
#                      ^
# SyntaxError: invalid syntax

# %%
Q6 이어서 풀기
