# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny5789/python/blob/main/2026_05_04_codingtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 💻 Q1. n의 배수
#
# 정수 num과 n이 매개 변수로 주어질 때,
#
# num이 n의 배수이면 1을 return n의 배수가 아니라면
#
# 0을 return하도록 solution 함수를 완성해주세요.

# %%
num = 98
n = 2

# %%
num = 34
n = 3

# %%
if num % n == 0:
    print("1")
else:
    print("0")
# Out:
# 1

# %% [markdown]
# # 💻 Q2. 뒤에서 5등까지
# 정수로 이루어진 리스트 num_list가 주어집니다.
#
#  num_list에서 가장 작은 5개의 수를 오름차순으로 담은 리스트를 return하도록 solution 함수를 완성해주세요.

# %%
num_list = [12, 4, 15, 46, 38, 1, 14]

# %%
num_list.sort()
print(num_list)
print(num_list[:5])
# Out:
# [1, 4, 12, 14, 15, 38, 46]
# [1, 4, 12, 14, 15]

# %% [markdown]
# # 💻 Q3. 0 떼기
# 정수로 이루어진 문자열 n_str이 주어질 때,
#
# n_str의 가장 왼쪽에 처음으로 등장하는 0들을 뗀 문자열을 return하도록 solution 함수를 완성해주세요.

# %%
n_str = "0010"

# %%
n_str = "854020"

# %%
# 하나씩 넣어 확인
# 0이 아닌 숫자를 만날 때 까지 0을 제거하자.
# if 0을 만나면 다음 꺼 확인
# if else(0이 아닌 숫자를 만나면) 뒤에는 모두 출력

# %%
for i in n_str:
    if i == '0':
        continue
    print(i)

    # 문제는 중간, 뒤에 있는 0 처리..!!--> lstrip()
# Out:
# 1

# %%
a = ''
a = n_str.lstrip("0")
print(a)
# Out:
# 10

# %% [markdown]
# # 💻 Q4. 배열 비교하기
# 이 문제에서 두 정수 배열의 대소관계를 다음과 같이 정의합니다.
#
#
# 두 배열의 길이가 다르다면, 배열의 길이가 긴 쪽이 더 큽니다.
#
# 배열의 길이가 같다면 각 배열에 있는 모든 원소의 합을 비교하여 다르다면 더 큰 쪽이 크고, 같다면 같습니다.
#
# 두 정수 배열 arr1과 arr2가 주어질 때,위에서 정의한 배열의 대소관계에 대하여
#
#  arr2가 크다면 -1,
#
#  arr1이 크다면 1,
#
#  두 배열이 같다면 0을 return
#
#   하는 solution 함수를 작성해 주세요.

# %%
arr1 = [49, 13]
arr2 = [70,11, 2]

# %%
arr1 = [100, 17, 84, 1]
arr2 = [55, 12, 65, 36]

# %%
arr1 = [1, 2, 3, 4, 5]
arr2 = [3, 3, 3, 3, 3]

# %%
if len(arr1) > len(arr2):
    print("1")

elif len(arr1) == len(arr2):
    if sum(arr1) > sum(arr2):
        print("1")
    elif sum(arr1) == sum(arr2):
        print("0")
    else:
        print("-1")

elif len(arr1) < len(arr2):
    print("-1")
# Out:
# 0

# %% [markdown]
# # 💻 Q5. 배열의 길이에 따라 다른 연산하기
# 정수 배열 arr과 정수 n이 매개변수로 주어집니다.
#
# arr의 길이가 홀수라면 arr의 모든 짝수 인덱스 위치에 n을 더한 배열을,
#
# arr의 길이가 짝수라면 arr의 모든 홀수 인덱스 위치에 n을 더한 배열을 return 하는 solution 함수를 작성해 주세요.

# %%
arr = [49, 12, 100, 276, 33]
n = 27

# %%
arr = [444, 555, 666, 777]
n = 100

# %%
if len(arr) % 2 == 0: #짝수이면
# 홀수 index + n
    for i in arr:
        i += n
        print(i)

else: # 홀수이면
# 짝수 index + n
    print(i)
# Out:
# 33

# %%
# 문제 5번 이어 풀기!
